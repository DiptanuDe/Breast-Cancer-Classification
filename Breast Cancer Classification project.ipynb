# %% [markdown]
# # Breast Cancer Classification

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns   
import matplotlib.pyplot as plt

import time
#import warnings library
import warnings
# ignore all warnings
warnings.filterwarnings('ignore')
# Any results you write to the current directory are saved as output.

# %%
df = pd.read_csv('breast cancer dataset.csv')

# %%
df.head(-5)
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 559    925291         B        11.51         23.93           74.52      403.5
# 560    925292         B        14.05         27.15           91.38      600.4
# 561    925311         B        11.20         29.37           70.67      386.0
# 562    925622         M        15.22         30.62          103.40      716.9
# 563    926125         M        20.92         25.09          143.00     1347.0
#
# ...

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
y = df['diagnosis']

# %%
X = df.drop(['id','diagnosis','Unnamed: 32'],axis = 1)
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
ax = sns.countplot(y,label="Count") # seaborn countplot for categorical variables

# %%
X.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
sns.pairplot(df.iloc[:,0:11],hue = 'diagnosis',diag_kws={'bw': 0.2})

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(X.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
# Out:
# <AxesSubplot:>

# %%
drop_list1 = ['perimeter_mean','area_mean','radius_worst','perimeter_worst','area_worst','concave points_mean','texture_worst','smoothness_worst','concavity_mean','concave points_mean','compactness_worst','concavity_worst','concave points_worst','fractal_dimension_worst','area_se','perimeter_se','concavity_se','fractal_dimension_se','symmetry_worst','radius_se','texture_se','smoothness_se','compactness_se','concave points_se','symmetry_se']
x_1 = X.drop(drop_list1,axis = 1 )        # do not modify x, we will use it later 
x_1.head()
# Out:
#    radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 0        17.99         10.38          0.11840           0.27760
# 1        20.57         17.77          0.08474           0.07864
# 2        19.69         21.25          0.10960           0.15990
# 3        11.42         20.38          0.14250           0.28390
# 4        20.29         14.34          0.10030           0.13280
#
#    symmetry_mean  fractal_dimension_mean
# 0         0.2419                 0.07871
# 1         0.1812                 0.05667
# 2         0.2069                 0.05999
# 3         0.2597                 0.09744
# 4         0.1809                 0.05883

# %%
f,ax = plt.subplots(figsize=(10, 10))
sns.heatmap(x_1.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score

# %%
# split data train 70 % and test 30 %
x_train, x_test, y_train, y_test = train_test_split(x_1, y, test_size=0.3, random_state=42)

# %%
x_train
# Out:
#      radius_mean  texture_mean  smoothness_mean  compactness_mean  \
# 149       13.740         17.91          0.07944           0.06376
# 124       13.370         16.39          0.07115           0.07325
# 421       14.690         13.98          0.10310           0.18360
# 195       12.910         16.33          0.07941           0.05366
# 545       13.620         23.23          0.09246           0.06747
# ..           ...           ...              ...               ...
# 71         8.888         14.64          0.09783           0.15310
# 106       11.640         18.33          0.11420           0.10170
# 270       14.290         16.82          0.06429           0.02675
# 435       13.980         19.62          0.10600           0.11330
# 102       12.180         20.52          0.08013           0.04038
#
#      symmetry_mean  fractal_dimension_mean
# 149         0.1473                 0.05580
# 124         0.1422                 0.05823
# ...

# %%
y_train
# Out:
# 149    B
# 124    B
# 421    B
# 195    B
# 545    B
#       ..
# 71     B
# 106    B
# 270    B
# 435    M
# 102    B
# Name: diagnosis, Length: 398, dtype: object

# %%
#random forest classifier with n_estimators=10 (default)
rf = RandomForestClassifier(random_state=43)
rf.fit(x_train,y_train)

ac = accuracy_score(y_test,rf.predict(x_test))
print('Accuracy is: ',ac)
cm = confusion_matrix(y_test,rf.predict(x_test))
sns.heatmap(cm,annot=True,fmt="d")
# Out:
# Accuracy is:  0.9649122807017544
# <AxesSubplot:>

# %%
import pickle

# %%
data = {"model":rf}
with open('saved_steps.pkl','wb') as file:
    pickle.dump(data,file)

# %%
with open('saved_steps.pkl','rb') as file:
    data = pickle.load(file)

RandomForest = data["model"]

# %%
y_test.value_counts()
# Out:
# B    108
# M     63
# Name: diagnosis, dtype: int64
